# %% [markdown]
# <a href="https://colab.research.google.com/github/ADavid096/ADavid096/blob/master/pagina_web_funcionalidades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
